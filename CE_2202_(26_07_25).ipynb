# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajmirahmed01/Python/blob/CE-2202/CE_2202_(26_07_25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Arithmatic operator
a=11 #11 is assigned as a value of a
b=2 #2 is assigned as a value of b
#'=' assigned operator
print(a)
print('a')
print(b)
print('b')
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
type(a//b)
# Out:
# 11
# a
# 2
# b
# 13
# 9
# 22
# 5.5
# 5
# int

# %%
#Volume
a=3 #length in meter
b=4 #width in meter
c=2 #height in meter
V=a*b*c #volume in cubic meter
print(V)
D=(a**2+b**2+c**2)**.5
print(D)
print('Diagonal','=',D)
# Out:
# 24
# 5.385164807134504
# Diagonal = 5.385164807134504

# %%
#Cylinder
d=2 #diameter in inch
h=4 #height in inch
x=(3.1416*d**2)/4
print(x)
y=d*h
print(y)
# Out:
# 3.1416
# 8
