# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajmirahmed01/Python/blob/CE-2201/ce_2201_10_08_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=input("Enter numbers separated by spaces:")
total=sum(map(int,n.split()))
print("The sum of the numbers is: ",total)
# Out:
# Enter numbers separated by spaces:6 7 8
# The sum of the numbers is:  21
