# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajmirahmed01/Python/blob/CE-2201/ce_2201_(12_08_25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(2,8):
 print(i,' ')
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for i in range(1,7,3):
 print(i)
# Out:
# 1
# 4

# %%
t=0
for i in range(1, 23,2):
 t+=i
 print(t, end=' ')
# Out:
# 1 4 9 16 25 36 49 64 81 100 121

# %%
t=0
for i in range(1, 22,2):
 t+=i
if i==21:
 print(f"summation of the series is {t}")
# Out:
# summation of the series is 121

# %%
t=0
for i in range(1, 22,2):
 t+=i
if i==21:
 break
print(f"summation of the series is {t}")
# Out:
#   File "/tmp/ipython-input-363136166.py", line 5
#     break
#     ^
# SyntaxError: 'break' outside loop
